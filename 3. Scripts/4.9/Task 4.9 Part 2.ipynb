# %% [markdown]
# # Import Library

# %%
# Import libraries 
import pandas as pd 
import numpy as np
import os

#Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %% [markdown]
# # Data Import

# %%
path = r'/Users/jacobyount/Documents/Data Analytics/Immersion 4/02.23.2023 Instacart Basket Analysis'

# %%
# Importing Combined Data

ords_prods_cust = pd.read_pickle(os.path.join(path, '2. Data', 'Prepared Data', 'combined_data.pkl'))

# %%
ords_prods_cust.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.239973e+07  3.239973e+07  3.239973e+07  3.239973e+07
# mean   1.710746e+06  1.029367e+05  1.714260e+01  2.738865e+00
# std    9.872994e+05  5.946623e+04  1.753544e+01  2.090089e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.559450e+05  5.142000e+04  5.000000e+00  1.000000e+00
# 50%    1.711052e+06  1.026140e+05  1.100000e+01  3.000000e+00
# 75%    2.565499e+06  1.543880e+05  2.400000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.239973e+07            3.239973e+07  3.239973e+07
# mean        1.342514e+01            1.110465e+01  2.559904e+04
# std         4.246397e+00            8.493136e+00  1.408498e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# 25%         1.000000e+01            5.000000e+00  1.354100e+04
# ...

# %% [markdown]
# # 2. Bar Chart, Histogram, Scatterplot, and Line Graph from example

# %%
# Creating a bar chart to represent orders day of week.

ords_prods_cust['order_dow'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Making a histogram representing the prices of products and their frequency.

hist = ords_prods_cust['prices'].plot.hist(bins = 25)

# %%
# Same histogram but a larger sample. (70 bin)

hist = ords_prods_cust['prices'].plot.hist(bins = 70)

# %%
# Creating a scatterplot. The outliers have been adjusted to NaN and saved in 4.8 scripts.

sns.scatterplot(x = 'prices', y = 'prices',data = ords_prods_cust)
# Out:
# <AxesSubplot:xlabel='prices', ylabel='prices'>

# %%
# Creating a sample holding True/false values to the test np.random.rand() <= .07 for line graph

np.random.seed(4)
dev = np.random.rand(len(ords_prods_cust)) <= 0.7

# %%
# Storing 70% of data in data frame big

big = ords_prods_cust[dev]

# %%
# Storing 30% of data in data frame small

small = ords_prods_cust[~dev]

# %%
# Checking data frame split usong len()
len(ords_prods_cust)
# Out:
# 32404859

# %%
len(big) + len(small)
# Out:
# 32404859

# %%
# Making sure the data frame is only columns needed for chart. 'prices' and 'order_dow'

df_small = small[['prices', 'order_dow']]

# %%
# Creating a line chart with small sample prices of products by order day of week.

line = sns.lineplot(data = df_small, x = 'order_dow', y = 'prices')

# %% [markdown]
# # 3. Creating a Histogram for Order_hour_of_day

# %%
# Creating a bar chart to represent orders hour of day.

Order_hour_bar = ords_prods_cust['order_hour_of_day'].value_counts().plot.bar()

# %% [markdown]
# The chart below shows that orders are more frequent during the hours 9 am - 4 pm. The lowest hours are 12 am - 6 am.

# %% [markdown]
# # 4. Bar Chart for the Loyalty Flag

# %%
# Creating a bar chart to represent Loyalty flag column.

loyalty_flag_bar = ords_prods_cust['loyalty_flag'].value_counts().plot.bar()

# %% [markdown]
# Regualr customers have a higher order frequency than loyal cutomers

# %% [markdown]
# # 5. Checking for differences in expeditures in prices by order hour of the day.

# %%
 # Making sure the data frame is only columns needed for chart. 'prices' and 'order_hour_of_day'
    
df_small2 = small[['prices', 'order_hour_of_day']]

# %%
# Creating a line chart with small sample of prices of products by order hour of day.

prices_by_hour_line = sns.lineplot(data = df_small2, x = 'order_hour_of_day', y = 'prices')

# %% [markdown]
#  The prices of products ordered stays around $7.80 from 12 pm on.

# %% [markdown]
# # 6. Correlation between age and family situation

# %%
 # Making sure the data frame is only columns needed for chart. 'age' and 'number of dependants'
    
df_small3 = small[['Age', 'num_dependants']]

# %%
# Creating a line chart with small sample of age and number of dependants.

line3 = sns.lineplot(data = df_small3, x = 'Age', y = 'num_dependants')

# %% [markdown]
# There isn't much to pull from this sample. There is a lot of variation. No real conclusion.

# %% [markdown]
# # 7. Correlation between Age and Spending Power

# %%
age_spending_power_scatter = sns.scatterplot(x = 'Age', y = 'income',data = ords_prods_cust)

# %% [markdown]
# The scatterplot above shows that people over 40 have a higher spending power.

# %% [markdown]
# # 8. Exporting Visualizations

# %%
Order_hour_bar.figure.savefig(os.path.join(path,'4. Analysis','Visualizations','order_hour_of_day.png'))

# %%
loyalty_flag_bar.figure.savefig(os.path.join(path,'4. Analysis','Visualizations','loyalty_flag_bar.png'))

# %%
prices_by_hour_line.figure.savefig(os.path.join(path,'4. Analysis','Visualizations','prices_by_hour_line.png'))

# %%
line3.figure.savefig(os.path.join(path,'4. Analysis','Visualizations','age_family_situation_line.png'))

# %%
age_spending_power_scatter.figure.savefig(os.path.join(path,'4. Analysis','Visualizations','age_spending_power_scatter.png'))
